# %%
# finding the connected camera ports

import cv2

def list_cameras(max_index=5):
    available_cameras = []
    for i in range(max_index):
        cap = cv2.VideoCapture(i)
        if cap.isOpened():
            ret, frame = cap.read()
            if ret:
                available_cameras.append(i)
                print(f"✅ Camera found at index {i}")
            cap.release()
    if not available_cameras:
        print("❌ No cameras detected by OpenCV")
    return available_cameras

cameras = list_cameras()
print("Detected camera indexes:", cameras)
# Out:
# ✅ Camera found at index 0
# Detected camera indexes: [0]

# %%
# establishing the camera connection

import cv2

# Try to open the first available camera (usually 0)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("❌ Cannot open camera")
else:
    print("✅ Camera opened")
    while True:
        ret, frame = cap.read()
        if not ret:
            print("❌ Failed to grab frame")
            break

        cv2.imshow('RGB Camera', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ✅ Camera opened
